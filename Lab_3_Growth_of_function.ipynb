# %% [markdown]
# # 1. Growth Of Function
# Time Complexity/Order of Growth defines the amount of time taken by any program with respect to the size of the input. Time Complexity specifies how the program would behave as the order of size of input is increased. So, Time Complexity is just a function of size of its input. We will go through some of basic and most common time complexities such as:
#
# - *Constant Time Complexity O(1) : constant running time*
# - *Linear Time Complexity O(n) : linear running time*
# - *Logarithmic Time Complexity O(log n) : logarithmic running time*
# - *Log-Linear Time Complexity O(n log n) : log-­linear running time*
# - *Polynomial Time Complexity O(n^c) : polynomial running time (c is a constant)*
# - *Exponential Time Complexity O(c^n) : exponential running time (c is a constant being raised to a power based on size of input)*

# %% [markdown]
# - **Created by Dr. Ajay

# %% [markdown]
# ## Constant time Complexity:O(1)
# An algorithm is said to have constant time with order O (1) when it is not dependent on the input size n. Irrespective of the input size n, the runtime will always be the same. See example below

# %%
# Load the Python libraries
import matplotlib.pyplot as plt

# %%
# Prob_1

def add_two_numbers(a, b):
    return a + b

n_values = list(range(1, 101))
time_values = []

for n in n_values:
    add_two_numbers(n, n + 1)
    time_values.append(1)

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(1) Constant Time Complexity for Addition")
plt.show()

# %%
#Prob_2:Take another example and write the code that runs in fixed amount of time or has fixed number of steps of execution no matter what is the size of input has constant time complexity.
#similar to example-1, also plot the graph (eg. even_odd )

import matplotlib.pyplot as plt

def check_even_odd(number):
    return 'Even' if number % 2 == 0 else 'Odd'

n_values = list(range(1, 101))  # Simulate different input sizes
time_values = []

for n in n_values:
    # The operation (modulo and comparison) takes a fixed amount of time
    # regardless of the value of n, as long as n fits in memory.
    check_even_odd(n)
    time_values.append(1) # Representing constant time

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(1) Constant Time Complexity for Even/Odd Check")
plt.show()

# %% [markdown]
# #Linear Time Complexity O(n) : linear running time
# - *An algorithm is said to have a linear time complexity when the running time increases linearly with the length of the input. When the function involves checking all the values in input data, with this order O(n).*

# %%
def linear_time_sum(numbers):
    total = 0
    for value in numbers:
        total += value
    return total

n_values = list(range(1, 101))
time_values = []

for n in n_values:
    data = list(range(n))
    linear_time_sum(data)
    time_values.append(n)

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(n) Linear Time Complexity")
plt.show()

# %%
#Prob_3:Take another example and write the code that runs in linear amount of time no matter what is the size of input..
#similar to example-2, also plot the graph (eg. even_oddcounts elements greater than zero)

import matplotlib.pyplot as plt

def count_greater_than_zero(numbers):
    count = 0
    for num in numbers:
        if num > 0:
            count += 1
    return count

n_values = list(range(1, 101))
time_values = []

for n in n_values:
    # Create a list of 'n' elements for input
    data = list(range(-n//2, n//2 + 1)) # Example data with positive, negative, and zero
    count_greater_than_zero(data)
    time_values.append(n) # Representing linear time complexity

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(n) Linear Time Complexity (Counting Greater Than Zero)")
plt.show()

# %% [markdown]
# #Logarithmic Time Complexity O(log n) : logarithmic running time
# - *An algorithm is said to have a logarithmic time complexity when it reduces the size of the input data in each step. This indicates that the number of operations is not the same as the input size. The number of operations gets reduced as the input size increases. Algorithms are found in binary tree or binary search functions. This involves the search of a given value in an array by splitting the array into two and starting searching in one split. This ensures the operation is not done on every element of the data.*

# %%
#Prob_4 Take Suitable example and write function that runs in logarithic time. plot graph as well similar to above example.

import matplotlib.pyplot as plt
import math

def binary_search(arr, target):
    low = 0
    high = len(arr) - 1
    steps = 0
    while low <= high:
        steps += 1
        mid = (low + high) // 2
        if arr[mid] == target:
            return steps  # Target found, return steps
        elif arr[mid] < target:
            low = mid + 1
        else:
            high = mid - 1
    return steps # Target not found, return steps for worst case

# Simulate input sizes
n_values = [2**i for i in range(1, 15)] # Using powers of 2 for clearer log behavior
time_values = []

for n in n_values:
    data = list(range(n)) # Create a sorted list
    # For worst-case log n, search for an element not present or at the ends
    steps = binary_search(data, n + 1) # Search for an element larger than any in the list
    time_values.append(steps)



# Plot 2: Linear X-axis (shows O(log n) flattening out)
plt.subplot(1, 2, 2) # 1 row, 2 columns, second plot
plt.plot(n_values, time_values, marker='o')
plt.xlabel("Input size n (linear scale)")
plt.ylabel("Steps (Time)")
plt.title("O(log n) Logarithmic Time (Linear X-axis)")
plt.grid(True)

plt.tight_layout() # Adjust layout to prevent overlapping titles/labels
plt.show()

# %% [markdown]
# #*Log-Linear Time Complexity O(n log n) : log-­linear running time*
#
#
# * When we call a Logarithmic Time Algorithm inside a loop, it would
# result into a Log-Linear Time Complexity program.

# %%
#Prob_5 Take Suitable example and write function that runs in log-linear time. plot the graph as well, similar to above example.

import time
import matplotlib.pyplot as plt
import random

def merge_sort(arr):
    if len(arr) <= 1:
        return arr

    mid = len(arr) // 2
    left = merge_sort(arr[:mid])
    right = merge_sort(arr[mid:])

    return merge(left, right)

def merge(left, right):
    result = []
    i = j = 0

    while i < len(left) and j < len(right):
        if left[i] <= right[j]:
            result.append(left[i])
            i += 1
        else:
            result.append(right[j])
            j += 1

    result.extend(left[i:])
    result.extend(right[j:])
    return result

# Input sizes
n_values = list(range(100, 5001, 500))
time_values = []

for n in n_values:
    data = random.sample(range(n*2), n)  # random list of size n

    start = time.time()
    merge_sort(data)
    end = time.time()

    elapsed = end - start
    time_values.append(elapsed)

# Plotting
plt.figure(figsize=(8,5))
plt.plot(n_values, time_values, marker="o", color="red")
plt.xlabel("Input size n")
plt.ylabel("Execution time (seconds)")
plt.title("O(n log n) Log-Linear Time Complexity: Merge Sort")
plt.grid(True)
plt.show()

# %% [markdown]
# ### Polynomial Time Complexity O(n^c) : polynomial running time (c is a constant)
#
# * When the computation time increases as function of N raised to some power, N being the size of input. Such a code has Polynomial Time complexity.

# %%
# Prob_6 Take Suitable example and write function that runs in log-linear time. plot the graph as well, similar to above example

import time
import matplotlib.pyplot as plt
import random

def quick_sort(arr):
    if len(arr) <= 1:
        return arr
    pivot = arr[len(arr) // 2]
    left = [x for x in arr if x < pivot]
    middle = [x for x in arr if x == pivot]
    right = [x for x in arr if x > pivot]
    return quick_sort(left) + middle + quick_sort(right)

# Input sizes
n_values = list(range(100, 5001, 500))
time_values = []

for n in n_values:
    data = random.sample(range(n*2), n)  # random list of size n

    start = time.time()
    quick_sort(data)
    end = time.time()

    elapsed = end - start
    time_values.append(elapsed)

# Plotting
plt.figure(figsize=(8,5))
plt.plot(n_values, time_values, marker="o", color="blue")
plt.xlabel("Input size n")
plt.ylabel("Execution time (seconds)")
plt.title("O(n log n) Log-Linear Time Complexity: Quick Sort")
plt.grid(True)
plt.show()

# %% [markdown]
# #Exponential Time Complexity O(c^n) : exponential running time (c is a constant being raised to a power based on size of input)
#
# * When the computation time of a code increases as function of X^N, N being the size of input. Such a code has Polynomial Time Complexity.

# %%
# Prob_7 Take Suitable example and write function that runs in polynomial time. plot the graph as well, similar to above example

import time
import matplotlib.pyplot as plt
import random

def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        for j in range(0, n-i-1):
            if arr[j] > arr[j+1]:
                arr[j], arr[j+1] = arr[j+1], arr[j]
    return arr

# Input sizes
n_values = list(range(10, 201, 20))  # step size increased for clarity
time_values = []

# Run multiple trials for each n
trials = 5

for n in n_values:
    elapsed_times = []
    for _ in range(trials):
        data = random.sample(range(n*2), n)  # random list of size n
        start = time.perf_counter()
        bubble_sort(data)
        end = time.perf_counter()
        elapsed_times.append(end - start)

    # Average time over trials
    avg_time = sum(elapsed_times) / trials
    time_values.append(avg_time)

# Plotting
plt.figure(figsize=(8,5))
plt.plot(n_values, time_values, marker="o", color="green", linestyle="--")
plt.xlabel("Input size n")
plt.ylabel("Average execution time (seconds)")
plt.title("O(n^2) Polynomial Time Complexity: Bubble Sort")
plt.grid(True)
plt.show()

# %% [markdown]
# #Importing required packages. plot graph similar to given figure
#
#
#
#
# ![1.png](data:image/png;base64,...)

# %%
#Prob_8 plot graph similar to above figure
import numpy as np
import matplotlib.pyplot as plt

# Generate data (start from 1 to avoid log(0))
n = np.linspace(1, 10, 500)

# Define functions
f = n                      # Linear
g = np.log2(n)             # Logarithmic (base 2)
h = n**2                   # Quadratic
k = 2**n                   # Exponential

# Create plot
plt.figure(figsize=(10, 6))
plt.plot(n, f, label='f(n) = n', linewidth=2)
plt.plot(n, g, label='g(n) = log₂(n)', linewidth=2)
plt.plot(n, h, label='h(n) = n²', linewidth=2)
plt.plot(n, k, label='k(n) = 2ⁿ', linewidth=2, linestyle='--')

# Formatting
plt.xlabel('n (Input size)')
plt.ylabel('Function value')
plt.title('Growth of Functions')
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.tight_layout()

# Show plot
plt.show()

# %%
# Write a function to perform quick sort and show that it has Logarithmic Time Complexity O(log n)
import time
import matplotlib.pyplot as plt
import random

def quick_sort(arr):
    if len(arr) <= 1:
        return arr
    pivot = arr[len(arr) // 2]
    left = [x for x in arr if x < pivot]
    middle = [x for x in arr if x == pivot]
    right = [x for x in arr if x > pivot]
    return quick_sort(left) + middle + quick_sort(right)

# Input sizes
n_values = list(range(100, 5001, 500))
time_values = []

for n in n_values:
    data = random.sample(range(n*2), n)  # random list of size n

    start = time.perf_counter()
    quick_sort(data)
    end = time.perf_counter()

    elapsed = end - start
    time_values.append(elapsed)

# Plotting
plt.figure(figsize=(8,5))
plt.plot(n_values, time_values, marker="o", color="purple")
plt.xlabel("Input size n")
plt.ylabel("Execution time (seconds)")
plt.title("Quick Sort Time Complexity (O(n log n))")
plt.grid(True)
plt.show()
